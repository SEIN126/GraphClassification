# %% [markdown]
# https://colab.research.google.com/drive/1I8a0DfQ3fI7Njc62__mVXUlcAleUclnb?usp=sharing#scrollTo=cNgkR8SRaU_P

# %%
import torch
from torch_geometric.data import DataLoader
import random
DATA_PATH = 'YOUR DATA PATH'

# %%
# load your dataset
train_dataset = torch.load(DATA_PATH)

# %%
random.shuffle(train_dataset)

# %%
# split to train and validation set
train_set = train_dataset[:int(len(train_dataset)*0.8)]
test_set = train_dataset[int(len(train_dataset)*0.8):]

# %%
# data to DataLoader
train_loader = DataLoader(train_set, batch_size=64, shuffle=True)
test_loader = DataLoader(test_set, batch_size=64, shuffle=False)

for step, data in enumerate(train_loader):
    print(f'Step {step + 1}:')
    print('=======')
    print(f'Number of graphs in the current batch: {data.num_graphs}')
    print(data)
    print()
# Out:
# Step 1:
# =======
# Number of graphs in the current batch: 64
# Batch(batch=[4757], edge_index=[2, 614402], ptr=[65], x=[4757, 1], y=[64])
#
# Step 2:
# =======
# Number of graphs in the current batch: 64
# Batch(batch=[3879], edge_index=[2, 278816], ptr=[65], x=[3879, 1], y=[64])
#
# Step 3:
# =======
# Number of graphs in the current batch: 64
# Batch(batch=[4375], edge_index=[2, 588736], ptr=[65], x=[4375, 1], y=[64])
#
# Step 4:
# =======
# Number of graphs in the current batch: 64
# Batch(batch=[5438], edge_index=[2, 997796], ptr=[65], x=[5438, 1], y=[64])
#
# Step 5:
# =======
# Number of graphs in the current batch: 64
# Batch(batch=[4667], edge_index=[2, 591492], ptr=[65], x=[4667, 1], y=[64])
#
# Step 6:
# =======
# Number of graphs in the current batch: 64
# Batch(batch=[4521], edge_index=[2, 510468], ptr=[65], x=[4521, 1], y=[64])
#
# Step 7:
# =======
# Number of graphs in the current batch: 64
# Batch(batch=[4198], edge_index=[2, 379736], ptr=[65], x=[4198, 1], y=[64])
#
# Step 8:
# =======
# Number of graphs in the current batch: 64
# Batch(batch=[4637], edge_index=[2, 516726], ptr=[65], x=[4637, 1], y=[64])
#
# Step 9:
# =======
# Number of graphs in the current batch: 64
# Batch(batch=[4366], edge_index=[2, 489946], ptr=[65], x=[4366, 1], y=[64])
#
# Step 10:
# =======
# Number of graphs in the current batch: 64
# Batch(batch=[5142], edge_index=[2, 718956], ptr=[65], x=[5142, 1], y=[64])
#
# Step 11:
# =======
# Number of graphs in the current batch: 64
# Batch(batch=[5245], edge_index=[2, 860784], ptr=[65], x=[5245, 1], y=[64])
#
# Step 12:
# =======
# Number of graphs in the current batch: 64
# Batch(batch=[5520], edge_index=[2, 830732], ptr=[65], x=[5520, 1], y=[64])
#
# Step 13:
# =======
# Number of graphs in the current batch: 64
# Batch(batch=[4301], edge_index=[2, 472444], ptr=[65], x=[4301, 1], y=[64])
#
# Step 14:
# =======
# Number of graphs in the current batch: 64
# Batch(batch=[4855], edge_index=[2, 602098], ptr=[65], x=[4855, 1], y=[64])
#
# Step 15:
# =======
# Number of graphs in the current batch: 64
# Batch(batch=[4557], edge_index=[2, 488218], ptr=[65], x=[4557, 1], y=[64])
#
# Step 16:
# =======
# Number of graphs in the current batch: 64
# Batch(batch=[4069], edge_index=[2, 301248], ptr=[65], x=[4069, 1], y=[64])
#
# Step 17:
# =======
# Number of graphs in the current batch: 64
# Batch(batch=[4209], edge_index=[2, 547652], ptr=[65], x=[4209, 1], y=[64])
#
# Step 18:
# =======
# Number of graphs in the current batch: 64
# Batch(batch=[4981], edge_index=[2, 752126], ptr=[65], x=[4981, 1], y=[64])
#
# Step 19:
# =======
# Number of graphs in the current batch: 64
# Batch(batch=[4445], edge_index=[2, 453232], ptr=[65], x=[4445, 1], y=[64])
#
# Step 20:
# =======
# Number of graphs in the current batch: 64
# Batch(batch=[4977], edge_index=[2, 763550], ptr=[65], x=[4977, 1], y=[64])
#
# Step 21:
# =======
# Number of graphs in the current batch: 64
# Batch(batch=[3864], edge_index=[2, 255664], ptr=[65], x=[3864, 1], y=[64])
#
# Step 22:
# =======
# Number of graphs in the current batch: 64
# Batch(batch=[5527], edge_index=[2, 906470], ptr=[65], x=[5527, 1], y=[64])
#
# Step 23:
# =======
# Number of graphs in the current batch: 64
# Batch(batch=[5267], edge_index=[2, 796502], ptr=[65], x=[5267, 1], y=[64])
#
# Step 24:
# =======
# Number of graphs in the current batch: 64
# Batch(batch=[3613], edge_index=[2, 313154], ptr=[65], x=[3613, 1], y=[64])
#
# Step 25:
# =======
# Number of graphs in the current batch: 64
# Batch(batch=[4726], edge_index=[2, 641398], ptr=[65], x=[4726, 1], y=[64])
#
# Step 26:
# =======
# Number of graphs in the current batch: 64
# Batch(batch=[4402], edge_index=[2, 592450], ptr=[65], x=[4402, 1], y=[64])
#
# Step 27:
# =======
# Number of graphs in the current batch: 64
# Batch(batch=[4606], edge_index=[2, 680588], ptr=[65], x=[4606, 1], y=[64])
#
# Step 28:
# =======
# Number of graphs in the current batch: 64
# Batch(batch=[5119], edge_index=[2, 630300], ptr=[65], x=[5119, 1], y=[64])
#
# Step 29:
# =======
# Number of graphs in the current batch: 64
# Batch(batch=[4333], edge_index=[2, 425862], ptr=[65], x=[4333, 1], y=[64])
#
# Step 30:
# =======
# Number of graphs in the current batch: 64
# Batch(batch=[5526], edge_index=[2, 741818], ptr=[65], x=[5526, 1], y=[64])
#
# Step 31:
# =======
# Number of graphs in the current batch: 64
# Batch(batch=[5445], edge_index=[2, 913652], ptr=[65], x=[5445, 1], y=[64])
#
# Step 32:
# =======
# Number of graphs in the current batch: 64
# Batch(batch=[5682], edge_index=[2, 1172134], ptr=[65], x=[5682, 1], y=[64])
#
# Step 33:
# =======
# Number of graphs in the current batch: 64
# Batch(batch=[5091], edge_index=[2, 720830], ptr=[65], x=[5091, 1], y=[64])
#
# Step 34:
# =======
# Number of graphs in the current batch: 64
# Batch(batch=[3853], edge_index=[2, 213536], ptr=[65], x=[3853, 1], y=[64])
#
# Step 35:
# =======
# Number of graphs in the current batch: 64
# Batch(batch=[5400], edge_index=[2, 712166], ptr=[65], x=[5400, 1], y=[64])
#
# Step 36:
# =======
# Number of graphs in the current batch: 64
# Batch(batch=[4551], edge_index=[2, 617318], ptr=[65], x=[4551, 1], y=[64])
#
# Step 37:
# =======
# Number of graphs in the current batch: 64
# Batch(batch=[4763], edge_index=[2, 634108], ptr=[65], x=[4763, 1], y=[64])
#
# Step 38:
# =======
# Number of graphs in the current batch: 64
# Batch(batch=[4837], edge_index=[2, 528498], ptr=[65], x=[4837, 1], y=[64])
#
# Step 39:
# =======
# Number of graphs in the current batch: 64
# Batch(batch=[4882], edge_index=[2, 443280], ptr=[65], x=[4882, 1], y=[64])
#
# Step 40:
# =======
# Number of graphs in the current batch: 64
# Batch(batch=[4968], edge_index=[2, 579692], ptr=[65], x=[4968, 1], y=[64])
#
# Step 41:
# =======
# Number of graphs in the current batch: 64
# Batch(batch=[5062], edge_index=[2, 650332], ptr=[65], x=[5062, 1], y=[64])
#
# Step 42:
# =======
# Number of graphs in the current batch: 64
# Batch(batch=[4383], edge_index=[2, 534292], ptr=[65], x=[4383, 1], y=[64])
#
# Step 43:
# =======
# Number of graphs in the current batch: 64
# Batch(batch=[5711], edge_index=[2, 871276], ptr=[65], x=[5711, 1], y=[64])
#
# Step 44:
# =======
# Number of graphs in the current batch: 64
# Batch(batch=[5151], edge_index=[2, 760178], ptr=[65], x=[5151, 1], y=[64])
#
# Step 45:
# =======
# Number of graphs in the current batch: 64
# Batch(batch=[5441], edge_index=[2, 876522], ptr=[65], x=[5441, 1], y=[64])
#
# Step 46:
# =======
# Number of graphs in the current batch: 64
# Batch(batch=[4357], edge_index=[2, 378520], ptr=[65], x=[4357, 1], y=[64])
#
# Step 47:
# =======
# Number of graphs in the current batch: 64
# Batch(batch=[4769], edge_index=[2, 714606], ptr=[65], x=[4769, 1], y=[64])
#
# Step 48:
# =======
# Number of graphs in the current batch: 64
# Batch(batch=[4545], edge_index=[2, 555166], ptr=[65], x=[4545, 1], y=[64])
#
# Step 49:
# =======
# Number of graphs in the current batch: 64
# Batch(batch=[5446], edge_index=[2, 967530], ptr=[65], x=[5446, 1], y=[64])
#
# Step 50:
# =======
# Number of graphs in the current batch: 64
# Batch(batch=[4493], edge_index=[2, 556520], ptr=[65], x=[4493, 1], y=[64])
#
# Step 51:
# =======
# Number of graphs in the current batch: 64
# Batch(batch=[5107], edge_index=[2, 830000], ptr=[65], x=[5107, 1], y=[64])
#
# Step 52:
# =======
# Number of graphs in the current batch: 64
# Batch(batch=[4331], edge_index=[2, 428342], ptr=[65], x=[4331, 1], y=[64])
#
# Step 53:
# =======
# Number of graphs in the current batch: 64
# Batch(batch=[4179], edge_index=[2, 483918], ptr=[65], x=[4179, 1], y=[64])
#
# Step 54:
# =======
# Number of graphs in the current batch: 64
# Batch(batch=[4907], edge_index=[2, 843340], ptr=[65], x=[4907, 1], y=[64])
#
# Step 55:
# =======
# Number of graphs in the current batch: 64
# Batch(batch=[4584], edge_index=[2, 596760], ptr=[65], x=[4584, 1], y=[64])

# %%
from torch.nn import Linear
import torch.nn.functional as F
from torch_geometric.nn import GCNConv
from torch_geometric.nn import global_mean_pool


class GCN(torch.nn.Module):
    """
    You can change and simply test your own GCN model.
    default,
    - three GCN layers
    - 64 hidden channels
    
    Try to various options, find our approximating hyper parameters
    """
    def __init__(self, hidden_channels=64):
        super(GCN, self).__init__()
        torch.manual_seed(12345)
        """
        GCNConv
        forward(x: torch.Tensor,
                edge_index: Union[torch.Tensor, torch_sparse.tensor.SparseTensor], 
                edge_weight: Optional[torch.Tensor] = None) → torch.Tensor
        """
        self.conv1 = GCNConv(1, hidden_channels) # 1 : feature 갯수
        self.conv2 = GCNConv(hidden_channels, hidden_channels)
        self.conv3 = GCNConv(hidden_channels, hidden_channels)
        self.lin = Linear(hidden_channels, 3)

    def forward(self, x, edge_index, batch):
        # 1. Obtain node embeddings 
        x = self.conv1(x, edge_index)
        x = x.relu()
        x = self.conv2(x, edge_index)
        x = x.relu()
        x = self.conv3(x, edge_index)
        x = x.relu()

        # 2. Readout layer
        x = global_mean_pool(x, batch)  # [batch_size, hidden_channels]

        # 3. Apply a final classifier
        x = F.dropout(x, p=0.5, training=self.training)
        x = self.lin(x)
        
        return x

# %%
model = GCN()
for n, m in model.named_children():
    print(n)
# Out:
# conv1
# conv2
# conv3
# lin

# %%
# check your device
device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")
print(f"Current Device : {device}")

model = GCN()
model.to(device)

# you can change the optimizer and learning rate to anything
optimizer = torch.optim.Adam(model.parameters(), lr=0.01)
criterion = torch.nn.CrossEntropyLoss()


def train():
    model.train()
    for data in train_loader:  # Iterate in batches over the training dataset.
        data.to(device)
        
        out = model(data.x, data.edge_index, data.batch)  # Perform a single forward pass.
        loss = criterion(out, data.y)  # Compute the loss.
        loss.backward()  # Derive gradients.
        optimizer.step()  # Update parameters based on gradients.
        optimizer.zero_grad()  # Clear gradients.


def test(loader):
    model.eval()

    correct = 0
    for i, data in enumerate(loader):  # Iterate in batches over the training/test dataset.
        data.to(device)
        out = model(data.x, data.edge_index, data.batch)  
        pred = out.argmax(dim=1)  # Use the class with highest probability.
        correct += (pred == data.y).sum() # Check against ground-truth labels.
    return correct / len(loader.dataset)  # Derive ratio of correct predictions.
# Out:
# Current Device : cuda:0

# %%
for epoch in range(1, 50):
    train()
    train_acc = test(train_loader)
    test_acc = test(test_loader)
    print(f'Epoch: {epoch:03d}, Train Acc: {train_acc:.4f}, Test Acc: {test_acc:.4f} ')
# Out:
# Epoch: 001, Train Acc: 0.5426, Test Acc: 0.5568
# Epoch: 002, Train Acc: 0.6131, Test Acc: 0.6148
# Epoch: 003, Train Acc: 0.6088, Test Acc: 0.6057
# Epoch: 004, Train Acc: 0.6074, Test Acc: 0.6057
# Epoch: 005, Train Acc: 0.6102, Test Acc: 0.6091
# Epoch: 006, Train Acc: 0.6153, Test Acc: 0.6136
# Epoch: 007, Train Acc: 0.6102, Test Acc: 0.6114
# Epoch: 008, Train Acc: 0.6071, Test Acc: 0.6000
# Epoch: 009, Train Acc: 0.6114, Test Acc: 0.6102
# Epoch: 010, Train Acc: 0.6148, Test Acc: 0.6068
# Epoch: 011, Train Acc: 0.6114, Test Acc: 0.6080
# Epoch: 012, Train Acc: 0.6142, Test Acc: 0.6080
# Epoch: 013, Train Acc: 0.6165, Test Acc: 0.6091
# Epoch: 014, Train Acc: 0.6099, Test Acc: 0.6080
# Epoch: 015, Train Acc: 0.6094, Test Acc: 0.6080
# Epoch: 016, Train Acc: 0.6077, Test Acc: 0.6080
# Epoch: 017, Train Acc: 0.6111, Test Acc: 0.6102
# Epoch: 018, Train Acc: 0.6139, Test Acc: 0.6034
# Epoch: 019, Train Acc: 0.6102, Test Acc: 0.6091
# Epoch: 020, Train Acc: 0.6099, Test Acc: 0.6057
# Epoch: 021, Train Acc: 0.6122, Test Acc: 0.6057
# Epoch: 022, Train Acc: 0.6105, Test Acc: 0.6068
# Epoch: 023, Train Acc: 0.6114, Test Acc: 0.6102
# Epoch: 024, Train Acc: 0.6105, Test Acc: 0.6091
# Epoch: 025, Train Acc: 0.6145, Test Acc: 0.6045
# Epoch: 026, Train Acc: 0.6099, Test Acc: 0.6080
# Epoch: 027, Train Acc: 0.6099, Test Acc: 0.6102
# Epoch: 028, Train Acc: 0.6111, Test Acc: 0.6080
# Epoch: 029, Train Acc: 0.6145, Test Acc: 0.6136
# Epoch: 030, Train Acc: 0.6114, Test Acc: 0.6136
# Epoch: 031, Train Acc: 0.6170, Test Acc: 0.6284
# Epoch: 032, Train Acc: 0.6105, Test Acc: 0.6080
# Epoch: 033, Train Acc: 0.6062, Test Acc: 0.6216
# Epoch: 034, Train Acc: 0.6094, Test Acc: 0.6057
# Epoch: 035, Train Acc: 0.6111, Test Acc: 0.6102
# Epoch: 036, Train Acc: 0.6170, Test Acc: 0.6114
# Epoch: 037, Train Acc: 0.6105, Test Acc: 0.6068
# Epoch: 038, Train Acc: 0.6108, Test Acc: 0.6068
# Epoch: 039, Train Acc: 0.6048, Test Acc: 0.6102
# Epoch: 040, Train Acc: 0.6128, Test Acc: 0.6125
# Epoch: 041, Train Acc: 0.6111, Test Acc: 0.6102
# Epoch: 042, Train Acc: 0.6153, Test Acc: 0.6102
# Epoch: 043, Train Acc: 0.5426, Test Acc: 0.5568
# Epoch: 044, Train Acc: 0.6173, Test Acc: 0.6068
# Epoch: 045, Train Acc: 0.6099, Test Acc: 0.6102
# Epoch: 046, Train Acc: 0.6170, Test Acc: 0.6080
# Epoch: 047, Train Acc: 0.6099, Test Acc: 0.6114
# Epoch: 048, Train Acc: 0.6145, Test Acc: 0.6136
# Epoch: 049, Train Acc: 0.6097, Test Acc: 0.6068
